# %%
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
#Membaca Dataset

df1 = pd.read_csv('diabetes_latih.csv')
df2 = pd.read_csv('diabetes_uji.csv')

# %%
#Proses Data_latih 

dfnew1 = df1.drop(df1.columns[[]], axis=1)
new1 = dfnew1.head()
a1 = dfnew1.shape
print(new1)
print("Total", a1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4564/708693313.py in <module>
#       2
#       3
# ----> 4 a1 = dfnew1.shape
#       5 print(new1)
#       6 print("Total", a1)
#
# NameError: name 'dfnew1' is not defined

# %%
#Proses Data_Uji

dfnew2 = df2.drop(df2.columns[[]], axis=1)
new2 = dfnew2.head()
a2 = dfnew2.shape
print(new2)
print("Total", a2)
# Out:
#    Kehamilan  Glukosa  TekananDarah  LemakTubuh  Insulin   BMI  Riwayat  Umur  \
# 0          6      148            72          35        0  33.6    0.627    50
# 1          1       85            66          29        0  26.6    0.351    31
# 2          8      183            64           0        0  23.3    0.672    32
# 3          1       89            66          23       94  28.1    0.167    21
# 4          0      137            40          35      168  43.1    2.288    33
#
#    Hasil
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
# Total (154, 9)

# %%
#Menggabungkan Data

dfnew3 = dfnew1.append(dfnew2)
new3 = dfnew3.head()
a3 = dfnew3.shape
print(new3)
print(a3)
# Out:
#    Kehamilan  Glukosa  TekananDarah  LemakTubuh  Insulin   BMI  Riwayat  Umur  \
# 0          8      188            78           0        0  47.9    0.137    43
# 1          7      152            88          44        0  50.0    0.337    36
# 2          2       99            52          15       94  24.6    0.637    21
# 3          1      109            56          21      135  25.2    0.833    23
# 4          2       88            74          19       53  29.0    0.229    22
#
#    Hasil
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
# (768, 9)

# %%
#Drop Diabetes

X = dfnew3.drop(columns=['Hasil'])
a4 = X.head()
print(a4)
# Out:
#    Kehamilan  Glukosa  TekananDarah  LemakTubuh  Insulin   BMI  Riwayat  Umur
# 0          8      188            78           0        0  47.9    0.137    43
# 1          7      152            88          44        0  50.0    0.337    36
# 2          2       99            52          15       94  24.6    0.637    21
# 3          1      109            56          21      135  25.2    0.833    23
# 4          2       88            74          19       53  29.0    0.229    22

# %%
#Hasil Dipisah dan Dibuatkan List sendiri

y = dfnew3['Hasil'].values
y[0:5]
# Out:
# array([1, 1, 0, 0, 0], dtype=int64)

# %%
#Heatmap

mask = np.zeros_like(dfnew3.corr(), dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

plt.title('Korelasi antar Fitur')
sns.heatmap(dfnew3.corr(),
           annot = True,
           mask = mask)
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_16004/1993025347.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(dfnew3.corr(), dtype = np.bool)
# <AxesSubplot:title={'center':'Korelasi antar Fitur'}>

# %%
#Menampilkan Grafik

plt.figure(figsize=(25,7))
hasil2 = sns.countplot(x='Umur', hue='Hasil', data=dfnew3, palette='Set1')
plt.title('Jumlah Hasil Berdasarkan Umur')
plt.show(hasil2)

# %%
#Memisahkan data Latih dan data Uji

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.168,random_state=1, stratify=y)

# %%
#Membuat KNN

neighbors = 12
knn = KNeighborsClassifier(neighbors)
best_model = knn.fit(x_train, y_train)

# %%
#Menampilkan Prediksi

arr = knn.predict(x_test)[0:5]
#print(arr)
score = []
score = knn.score(x_test, y_test)

# %%
print("Jumlah K : ", neighbors)
print("Akruasi : ", score * 100, "%")
# Out:
# Jumlah K :  12
# Akruasi :  70.76923076923077 %

# %%
#Featured Scaling

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
#Meload model - KNN

classifier = KNeighborsClassifier(n_neighbors=12, p=2, metric = 'euclidean')

# %%
#fitting Model

classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=12)

# %%
#Membuat Predictions

y_pred = classifier.predict(x_test)

# %%
#Evaluasi Model

conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
print(f1_score(y_test, y_pred) * 100, '%')
# Out:
# [[76  9]
#  [28 17]]
# 47.88732394366198 %

# %%
#Menghitung Akurasi

print(accuracy_score(y_test, y_pred) * 100, '%')
plt.show()
# Out:
# 71.53846153846153 %

# %%
error = []
epen = []

#Hasil Kalkulasi Eror untuk nilai K dari 1 sampai 30

for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    pred_i = knn.predict(x_test)
    emen = np.mean(pred_i != y_test)
    epen = error.append(emen)
    
    print (i, emen)
# Out:
# 1 0.33076923076923076
# 2 0.3
# 3 0.2692307692307692
# 4 0.23076923076923078
# 5 0.2692307692307692
# 6 0.2846153846153846
# 7 0.3
# 8 0.27692307692307694
# 9 0.27692307692307694
# 10 0.2846153846153846
# 11 0.27692307692307694
# 12 0.2846153846153846
# 13 0.3
# 14 0.3
# 15 0.2846153846153846
# 16 0.27692307692307694
# 17 0.2846153846153846
# 18 0.2692307692307692
# 19 0.2846153846153846
# 20 0.2692307692307692
# 21 0.26153846153846155
# 22 0.26153846153846155
# 23 0.26153846153846155
# 24 0.25384615384615383
# 25 0.23846153846153847
# 26 0.24615384615384617
# 27 0.24615384615384617
# 28 0.25384615384615383
# 29 0.26153846153846155

# %%
#Menampilkan Grafik Eror Nilai K

plt.figure(figsize=(12, 6))
plt.plot(range(1, 30), error, color='green', linestyle='-', marker='o', 
         markerfacecolor='red', markersize=10)
plt.title('Rata - rata Eror Nilai K')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
plt.show()

# %%
#Menampilkan Akurasi 

score = []
for n in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(x_train, y_train)
    knnscore = knn.score(x_test, y_test)
    sken = score.append(knnscore)
    print(n, knnscore)
# Out:
# 1 0.6692307692307692
# 2 0.7
# 3 0.7307692307692307
# 4 0.7692307692307693
# 5 0.7307692307692307
# 6 0.7153846153846154
# 7 0.7
# 8 0.7230769230769231
# 9 0.7230769230769231
# 10 0.7153846153846154
# 11 0.7230769230769231
# 12 0.7153846153846154
# 13 0.7
# 14 0.7
# 15 0.7153846153846154
# 16 0.7230769230769231
# 17 0.7153846153846154
# 18 0.7307692307692307
# 19 0.7153846153846154
# 20 0.7307692307692307
# 21 0.7384615384615385
# 22 0.7384615384615385
# 23 0.7384615384615385
# 24 0.7461538461538462
# 25 0.7615384615384615
# 26 0.7538461538461538
# 27 0.7538461538461538
# 28 0.7461538461538462
# 29 0.7384615384615385

# %%
#Menampilkan Grafik  Akruasi tiap Nilai K

plt.figure(figsize=(12,6))
plt.plot(range(1,30), score, color='green', linestyle='-', marker='o',
        markerfacecolor='red', markersize=10)
plt.title('Ks Akurasi')
plt.xlabel('K Value')
plt.ylabel('Akurasi')
plt.show()

# %%
#Simpan model pakai PICKLE

with open('knn_pickle', 'wb') as r:
    pickle.dump(knn,r)

# %%
with open('knn_pickle', 'rb') as r:
    knnp = pickle.load(r)

# %%
y_pred = knnp.predict(x_test)

round(accuracy_score(y_test, y_pred),12)
# Out:
# 0.738461538462
